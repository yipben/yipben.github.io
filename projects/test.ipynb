# %% [markdown]
# ## Test Article

# %%
import matplotlib.pyplot as plt
import numpy as np

t = np.arange(0.0, 2.0, 0.01)
s = 1 + np.sin(2*np.pi*t)
plt.plot(t, s)
plt.show()

# %% [markdown]
# This is some text about my graph. Blah blah blah blah blah blah

# %%
print('hello world')
# Out:
# hello world
